# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime as dt

# %% [markdown]
# 1. Create a simple plot using plt.plot(). Plot a single Python list [3,7,8,9,12].

# %%
plt.plot([3,7,8,9,12])

# %% [markdown]
# 2. Create two lists, one called x, one called y, each with 5 numbers in them.
# a.	Plot them using plt.plot().
# b.	Create a plot using plt.subplots() and then add x & y on the axes.

# %%
x=(3,7,8,9,12)
y=(1,2,3,4,5)
plt.plot(x)
plt.plot(y)
fig, ax = plt.subplots()
ax.plot(x,y)
plt.title('x vs. y')
ax.set_xlabel('x',color='red',size='large')
ax.set_ylabel('y',color='red',size='large')
plt.show()

# %% [markdown]
# 3.	Create an 1D array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X.
# a.	Create a plot using plt.subplots() and plot X versus X^2
# b.	Create a scatter plot of X versus the exponential of X (np.exp(X))

# %%
X= np.arange(100)
X2=np.array(X**2)
expX=np.exp(X)
fig,ax1= plt.subplots()
plt.title('x vs. x**2')
ax1.set_xlabel('x',color='red',size='large')
ax1.set_ylabel('x**2',color='red',size='large')
ax1.plot(X,X2)
fig,ax2= plt.subplots()
plt.title('x vs. exp(x)')
ax2.set_xlabel('x',color='red',size='large')
ax2.set_ylabel('exp(x)',color='red',size='large')
ax2.plot(X,expX)
plt.show()

# %% [markdown]
# 4.	Import car-sales.csv  into a DataFrame called car_sales and view.
# a.	Try to plot the 'Price' column using the plot() function
# b.	Try to plot the ''Odometer (KM)” column using the plot() function
# Comment on why one doesn't work while another do?

# %%
car_sales=pd.read_csv('car-sales.csv')
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   $4,000
# 1   Honda    Red          87899      4   $5,000
# 2  Toyota   Blue          32549      3   $7,000
# 3     BMW  Black          11179      5  $22,000
# 4  Nissan  White         213095      4   $3,500

# %%
fig,ax3=plt.subplots()
ax3.plot(car_sales['Price'])
ax3.set_ylabel('Price',color='red',size='large')
fig,ax4=plt.subplots()
ax4.plot(car_sales['Odometer (KM)'])
ax4.set_ylabel('Odometer (KM)',color='red',size='large')
plt.show()
#both works for me.

# %% [markdown]
# 5.	Remove all the symbols (\$\,)from the 'Price' column and convert  and update it to  64-bit int numbers using astype(‘int64’) Hint. Look for string functions like replace/strip). The data frame will be look like after that:

# %%
car_sales['Price']=car_sales['Price'].str.replace('$','').str.replace(',','').astype('int64')
car_sales.head()
# Out:
# C:\Users\radja\AppData\Local\Temp\ipykernel_5908\1421979085.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   car_sales['Price']=car_sales['Price'].str.replace('$','').str.replace(',','').astype('int64')
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500

# %% [markdown]
# 6.	Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column look up the cumsum() function.

# %%
car_sales['Total Sales']=np.cumsum(car_sales['Price'])
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500

# %% [markdown]
# 7.	Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today). Check out “date_range” function and keep the periods=len(car_sales). The data frame will be look like that:

# %%
car_sales['Sale Date']=pd.date_range(dt.today(), periods=len(car_sales))
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  \
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500
#
#                    Sale Date
# 0 2023-10-01 15:17:13.871394
# 1 2023-10-02 15:17:13.871394
# 2 2023-10-03 15:17:13.871394
# 3 2023-10-04 15:17:13.871394
# 4 2023-10-05 15:17:13.871394

# %% [markdown]
# 8.	Use the matplotlib line plot function to plot the 'Price' column versus the 'Total Sales' column (Give proper title and appropriate labels.

# %%
fig,ax5= plt.subplots()
plt.title('Price vs. Total Sales line plot')
ax5.set_xlabel('Price',color='black',size='large')
ax5.set_ylabel('Total Sales',color='black',size='large')
ax5.plot(car_sales['Price'],car_sales['Total Sales'])

# %% [markdown]
# 9.	Create a matplotlib scatter plot of the 'Odometer (KM)' vs 'Price' column.

# %%
fig,ax6=plt.subplots()
plt.title('Odometer vs. Price scatter plot')
ax6.set_xlabel('Odometer (KM)',color='black',size='large')
ax6.set_ylabel('Price',color='black',size='large')
ax6.scatter(car_sales['Odometer (KM)'],car_sales['Price'])
plt.show()

# %% [markdown]
# 10.	Create a matplotlib bar graph of the 'Make' vs 'Odometer (KM)' columns

# %%
fig,ax7=plt.subplots()
plt.title('Make vs. Odometer bar plot')
ax7.set_xlabel('Make',color='black',size='large')
ax7.set_ylabel('Odometer (KM)',color='black',size='large')
ax7.bar(car_sales['Make'],car_sales['Odometer (KM)'])
plt.show()

# %% [markdown]
#
# 11.	Create a histogram of the 'Make' column

# %%
fig,ax8=plt.subplots()
plt.title('Histogram of car make')
ax8.set_xlabel('Make',color='black',size='large')
ax8.hist(car_sales['Make'])
plt.show()

# %% [markdown]
# 12.	Create a subplot of multiple plots ( step 8,9,10,11).

# %%
fig=plt.figure(figsize=(16,8))

ax5= fig.add_subplot(221)
ax5.set_title('Price vs. Total Sales line plot')
ax5.set_xlabel('Price',color='black',size='large')
ax5.set_ylabel('Total Sales',color='black',size='large')
ax5.plot(car_sales['Price'],car_sales['Total Sales'])

ax6=fig.add_subplot(222)
ax6.set_title('Odometer vs. Price scatter plot')
ax6.set_xlabel('Odometer (KM)',color='black',size='large')
ax6.set_ylabel('Price',color='black',size='large')
ax6.scatter(car_sales['Odometer (KM)'],car_sales['Price'])

ax7=fig.add_subplot(223)
ax7.set_title('Make vs. Odometer bar plot')
ax7.set_xlabel('Make',color='black',size='large')
ax7.set_ylabel('Odometer (KM)',color='black',size='large')
ax7.bar(car_sales['Make'],car_sales['Odometer (KM)'])

ax8=fig.add_subplot(224)
ax8.set_title('Histogram of car make')
ax8.set_xlabel('Make',color='black',size='large')
ax8.hist(car_sales['Make'])

plt.show()

# %% [markdown]
# 13.	Create a box plot of Colour and Total Sales using seaborn plot

# %%
sns.boxplot(x='Colour',y='Total Sales',data=car_sales)
plt.show()

# %% [markdown]
#
# 14.	Find out the relationship bwtween "Total Sales" and "Odometer (KM)" using linear regression with no error bar and car make will determine the hue

# %%
sns.lmplot(x='Total Sales',y='Odometer (KM)',data=car_sales,ci=False,hue='Make')
plt.show()

# %% [markdown]
# 15.	Draw pair plot for all possible combinations.

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price', 'Total Sales',
#        'Sale Date'],
#       dtype='object')

# %%
sns.pairplot(x_vars='Make',y_vars='Colour',data=car_sales)
sns.pairplot(x_vars='Make',y_vars='Odometer (KM)',data=car_sales)
sns.pairplot(x_vars='Make',y_vars='Doors',data=car_sales)
sns.pairplot(x_vars='Make',y_vars='Price',data=car_sales)
sns.pairplot(x_vars='Make',y_vars='Total Sales',data=car_sales)
sns.pairplot(x_vars='Make',y_vars='Sale Date',data=car_sales)

sns.pairplot(x_vars='Colour',y_vars='Odometer (KM)',data=car_sales)
sns.pairplot(x_vars='Colour',y_vars='Doors',data=car_sales)
sns.pairplot(x_vars='Colour',y_vars='Price',data=car_sales)
sns.pairplot(x_vars='Colour',y_vars='Total Sales',data=car_sales)
sns.pairplot(x_vars='Colour',y_vars='Sale Date',data=car_sales)

sns.pairplot(x_vars='Odometer (KM)',y_vars='Doors',data=car_sales)
sns.pairplot(x_vars='Odometer (KM)',y_vars='Price',data=car_sales)
sns.pairplot(x_vars='Odometer (KM)',y_vars='Total Sales',data=car_sales)
sns.pairplot(x_vars='Odometer (KM)',y_vars='Sale Date',data=car_sales)

sns.pairplot(x_vars='Doors',y_vars='Price',data=car_sales)
sns.pairplot(x_vars='Doors',y_vars='Total Sales',data=car_sales)
sns.pairplot(x_vars='Doors',y_vars='Sale Date',data=car_sales)

sns.pairplot(x_vars='Price',y_vars='Total Sales',data=car_sales)
sns.pairplot(x_vars='Price',y_vars='Sale Date',data=car_sales)

sns.pairplot(x_vars='Total Sales',y_vars='Sale Date',data=car_sales)
# Out:
# C:\Users\radja\anaconda3\lib\site-packages\seaborn\axisgrid.py:1242: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)

# %% [markdown]
# 16.	Find out Pearson correlation between 'Total Sales','Price','Odometer (KM)'. Comment on the correlation

# %%
df=pd.DataFrame(car_sales,columns=['Total Sales','Price','Odometer (KM)'])
#car_sales['Total Sales']['Price']['Odometer (KM)']
sns.heatmap(df.corr(),annot=True,annot_kws={'size':30},linewidth=1)
plt.show()

# %%
matrix=car_sales.drop(['Make','Colour','Doors','Sale Date'],axis=1)
matrix.corr()
sns.heatmap(matrix.corr(),annot=True, annot_kws={'size': 30},linewidth=1)
plt.show()
#The correlation between odometer and price is a relatively strong inverse correlation while the correlation between price and total sales is a relatively weak direct correlation.

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  \
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500
#
#                    Sale Date
# 0 2023-10-01 15:17:13.871394
# 1 2023-10-02 15:17:13.871394
# 2 2023-10-03 15:17:13.871394
# 3 2023-10-04 15:17:13.871394
# 4 2023-10-05 15:17:13.871394

# %%
matrix.corr()
# Out:
#                Odometer (KM)     Price  Total Sales
# Odometer (KM)       1.000000 -0.631781    -0.321634
# Price              -0.631781  1.000000     0.164732
# Total Sales        -0.321634  0.164732     1.000000
